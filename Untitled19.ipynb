# %% [markdown]
# #**¿Que Aprendí?**
#
# **Muestreo aleatorio:** Procedimiento de selección de la muestra en el que todos y cada uno de los elementos de la población tiene una cierta probabilidad de resultar elegidos .
#
# **1-¿Que se?**
#
# R= Lo que sabia es que de una poblacion tomamos una muestra aleatoria de datos.
#
# **2-¿Que quiero saber?**
#
# R=Me gustaria aprender como utilizarlo para analizar ciertos datos.
#
# **3-¿Que Aprendí?**
#
# R= Aprendí un codigo para sacar el muestreo aleatorio el cual es el siguente:

# %%
sample_size = #(Numero aleatorio)
sample = data.samle(n= sample_size, random_state = #(Numero menor a sample_size por que si no dara error)#)

# %% [markdown]
# **Muestreo aleatorio sistematico:** Se selecciona una muestra tomando cada k-ésima unidad de la población, una vez que las unidades de muestreo están numeradas o arregladas de alguna forma. La letra k es la razón de muestreo, esto es, la razón del tamaño de la población correspondiente al tamaño de la muestra. Organizamos miembros de una población en cierto orden, elegimos un punto de partida aleatorio y seleccionamos cada miembro en un intervalo determinado.
#
# **1-¿Que se?**
#
# R= Desconocia por completo el hecho de una muestra aleatoria sistematica.
#
# **2-¿Que quiero saber?**
#
# R= Me gustaria saber que son y como sacarlas en probabilidad.
#
# **3-¿Que Aprendí?**
#
# R= Aprendí que una muestra sistematica es organizar nuestra poblacion en un orden para elegir un punto de partida aleatorio y selecionamos los intervalos de manera determinada.El codigo es el siguiente:

# %%
sample_size = 50
interval = population_size // sample_size
systematic_sample = data.iloc[::interval]

print("Muestra obtenida por muestreo sistematico:")
display(systematic_sample)

# %%
#se mostrara a continuacion una imagen de la formula de una muestra sistematica:

# %% [markdown]
# ![texto del vínculo](https://drive.google.com/uc?id=1gw9fdaetb6bXK-Bf18GkR2CK9He5LHRa)

# %% [markdown]
# **Muestreo por conveniencia**: La muestra se elige de acuerdo con la conveniencia de investigador, le permite elegir de manera arbitraria cuántos participantes puede haber en el estudio.
#
# **1-¿Que se?**
#
# R= No conocia este termino pero puedo intuir que es tomar datos de nuestra poblacion que mas nos convengan como por ejemplo tomar los datos mas recientes para realizar un analisis.
#
# **2-¿Que quiero saber?**
#
# R= Como hacer una muestreo por conveniencia
#
# **3-¿Que aprendi?**
#
# R= Aprendi que un muestreo por conveniencia son los datos tomados por un investigador segun su conveniencia.

# %%
convenience_sample = data.head(50)

print("Muestra de conveniencia:")
display(convenience_sample)

# %% [markdown]
# En el codigo de arriba se pude decir que es un muestreo por conveniencia por que el investigador solo esta tomado los primeros 50 datos sin tomar a consideracion los demas datos.

# %% [markdown]
# ![texto del vínculo](https://drive.google.com/uc?id=10UZb1qooW8ZuakiHl_6GAJ7GA0rXin86)

# %% [markdown]
# #**Histogramas**
#
# **Histogramas**: gráficos que indican la frecuencia de un hecho mediante una distribución de los datos. Los histogramas muestran la forma de sus datos. El eje horizontal muestra sus valores de datos, con cada barra correspondiendo a un rango de valores.
#
# **1-¿Que se?**
#
# R= Se que los historigramas son graficas como poligonos de frecuencia o los mas conocidos los de barra y la grafica de pastel
#
# **2-¿Que quiero saber?**
#
# R= Me gustaria saber como sacar ese tipo de graficas en colab
#
# **3-¿Que Aprendí?**
#
# R= Que los historigramas son graficas que representan los datos.

# %% [markdown]
# ![texto del vínculo](https://drive.google.com/uc?id=1gCP1oDZKF3HnsL-oskOeKKS2WOmMMxEG)

# %% [markdown]
# **Diagrama de arbol**: Diagrama Sistemático, es una herramienta de la calidad que permite obtener una visión de conjunto de los medios necesarios para alcanzar una meta o resolver un problema.
#
# **1-¿Que se?**
#
# R=La verdad desconosco que son los diagramas de arbol
#
# **2.¿Que quiero saber?**
#
# R= Me gustaria saber que son y como podria utilizarlos
#
# **3-¿Que Aprendí?**
#
# R= Aprendi que es una manera de graficar los datos que tenemos para interpretarlo de una manera mas facil.

# %% [markdown]
# ![texto del vínculo](https://drive.google.com/uc?id=1hY9RpFJIujcDsdOVNNDbsPUTtoLMgWaL)

# %% [markdown]
# **Diagrama de caja y bigote**: Muestra la distribución de datos en cuartiles, resaltando el promedio y los valores atípicos. Las cajas podrán tener líneas que se extienden verticalmente llamadas “bigotes”.Los diagramas de caja utilizan el cálculo de percentiles para determinar los valores de los cuartiles. Por ejemplo, el primer cuartil es igual al percentil 25. La parte de la caja del diagrama siguiente ilustra el 50 por ciento medio de los valores de los datos, también conocido como rango intercuartílico o IQR.
#
# **percentiles**: sirven para encontrar puntos específicos en los datos no agrupados o agrupados que estemos manejando en nuestra investigación
#
# **1-¿Que se?**
#
# R=Desconosco completamente que sea este tipo de diagrama
#
# **2-¿Que quiero saber?**
#
# R=Me gustaria saber que es
#
# **3-¿Que Aprendí?**
#
# R=Que es una manera de graficar nuestros datos y que los percentiles nos ayudan a encontrar puntos especificos de nuestros datos.

# %% [markdown]
# ![texto del vínculo](https://drive.google.com/uc?id=1aSsfIghBTMtQYLeu_cqyvaAC-N0joBAQ)

# %% [markdown]
# **Diagrama tallo y hoja**: Un diagrama de tallos y hojas muestra datos numéricos al separar cada punto de datos en una "hoja" (normalmente el último dígito) y un "tallo" (el dígito o dígitos principales).
#
# **1-¿Que se?**
#
# R= Se que el diagrama tallo hoja nos ayuda a organizar datos de manera mas rapida y sencilla.
#
# **2-¿Que quiero saber?**
#
# R=Como utilizarlo en mi vida diaria
#
# **3-¿Que Aprendí?**
#
# R=Aprendi que estos diagramas nos ayudan a encontrar la media de los datos y facilitan los procesos de organizarlos a mano

# %% [markdown]
# ![texto del vínculo](https://drive.google.com/uc?id=1q3RRE48L467j94yFaqyE7j4O0P_l86BG)
